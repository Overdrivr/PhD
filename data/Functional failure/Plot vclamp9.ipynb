# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import os
import collections
import pandas as pd
import matplotlib as mp
from matplotlib import gridspec
mp.style.use('classic')

# Read simulation files
def datafileread(measurename,skipfirstrows):
    # Reading Datafiles
    path = measurename
    data = np.genfromtxt(path,
                        skip_header=skipfirstrows,
                        delimiter=',',
                        dtype=(float,float),
                        unpack=True)
    return data

# measurement
dummy, time, vboost, vclamp9, v1p0, v2p5a = datafileread('total_fullblock_m100v.csv',19)

time *= 1e6

# %%
plt.figure(figsize=(10, 3.5)) 
plt.plot(time, vclamp9, label="simulation")
plt.xlabel("Time (μs)")
plt.ylabel("Voltage (V)")
plt.xlim([52, 57])
plt.legend(loc="best")
plt.tight_layout()
plt.savefig("../../src/3/figures/vclamp9.png", pad_inches=0.3)
plt.show()

# %%
plt.figure(figsize=(5, 3.5)) 
plt.plot(time, vclamp9, label="simulation")
plt.xlabel("Temps (μs)")
plt.ylabel("Tension (V)")
plt.xlim([53.5, 55.5])
plt.legend(loc="best")
plt.tight_layout()
plt.savefig("./vclamp9_xs.png", pad_inches=0.3)
plt.show()
