# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import os
import collections
import pandas as pd

import seaborn as sns
import matplotlib as mp
from matplotlib.ticker import FormatStrFormatter
from matplotlib.colors import LogNorm

sns.set()

# Read simulation files
def datafileread(measurename,skipfirstrows):
    # Reading Datafiles
    path = measurename
    data = np.genfromtxt(path,
                        skip_header=skipfirstrows,
                        delimiter=',',
                        dtype=(float,float),
                        unpack=True)
    return data

# measurement
tlp_v,tlp_length,input_v,amplitude,width = datafileread('cz_vpre_V5.csv',19)

print("Width : %E (s) -> %E (s)" % (np.amin(width), np.amax(width)))

tlp_length = np.round(tlp_length * 1e9, decimals=1)

# Add DC voltage value
#tlp_v += 12 

df_amplitude = pd.DataFrame({'x': tlp_length, 'y': tlp_v, 'z': amplitude})
df_amplitude = df_amplitude.pivot(index='y',columns='x', values='z')

df_width = pd.DataFrame({'x': tlp_length, 'y': tlp_v, 'z': width})
df_width = df_width.pivot(index='y',columns='x', values='z')
df_width = df_width.multiply(1e9)
df_width.iloc[:,20:]
# Out:
# Width : 1.068270E-08 (s) -> 2.124280E-06 (s)
# x        239.5     280.7     329.0     385.7     452.0     529.8     621.0   \
# y
# -40.0   721.330   809.293   920.400  1044.210  1182.240  1344.350  1511.720
# -38.0   702.909   792.505   892.657  1005.730  1140.000  1289.520  1464.880
# -36.0   929.000   770.078   869.000   979.632  1102.910  1242.410  1404.890
# -34.0   932.616   989.227  1057.000   950.916  1072.650  1206.310  1353.000
# -32.0   938.787   990.799  1058.000  1138.520  1228.470  1171.090  1314.220
# -30.0   949.206   995.604  1056.840  1134.270  1226.400  1331.510  1275.430
# -28.0   966.943  1007.230  1061.350  1132.660  1220.480  1322.730  1436.330
# -26.0   999.897  1037.570  1086.430  1149.140  1226.100  1320.850  1428.050
# -24.0  1019.070  1061.070  1108.000  1166.630  1239.820  1329.290  1434.170
# -22.0  1019.480  1075.530  1131.540  1189.220  1257.600  1340.730  1439.590
# -20.0  1002.090  1063.740  1132.000  1206.400  1284.110  1365.930  1459.430
# -18.0   975.170  1035.110  1103.670  1181.820  1270.550  1370.570  1481.920
# -16.0   939.877   995.802  1059.280  1132.160  1216.350  1313.410  1425.140
# -14.0   820.851   866.846   920.913   983.358  1055.800  1139.160  1236.140
# -12.0   758.000   808.000   864.545   928.571  1001.720  1085.470  1182.380
# -10.0   249.492   291.803   341.000   664.932   758.085   854.577   962.000
# -8.0    240.000   281.236   329.548   386.175   452.549   530.345   621.530
# -6.0    239.919   281.138   329.451   386.079   452.453   530.250   621.435
# -4.0    245.086   285.823   333.764   390.194   456.438   534.112   625.257
# -2.0    250.060   291.126   339.340   395.914   462.260   540.000   631.228
#
# x        727.9     853.2    1000.0
# y
# -40.0  1690.500  1896.610  2124.28
# -38.0  1646.000  1842.160  2067.00
# -36.0  1594.730  1785.320  2007.29
# -34.0  1529.330  1735.560  1951.16
# -32.0  1470.880  1663.430  1887.76
# -30.0  1430.550  1603.140  1808.74
# -28.0  1557.750  1555.760  1748.43
# -26.0  1549.750  1689.090  1697.19
# -24.0  1548.360  1678.510  1834.62
# -22.0  1551.220  1681.920  1833.00
# -20.0  1566.000  1687.430  1833.11
# -18.0  1599.670  1720.620  1858.50
# -16.0  1552.810  1698.370  1863.56
# -14.0  1349.700  1482.400  1637.34
# -12.0  1293.840  1423.210  1573.76
# -10.0  1081.720  1215.000  1367.94
# -8.0    728.409   853.681  1000.51
# -6.0    728.313   853.586  1000.42
# -4.0    732.123   857.393  1004.17
# -2.0    738.107   863.379  1010.21

# %%
df_amplitude.iloc[:,20:]
# Out:
# x        239.5     280.7     329.0     385.7     452.0     529.8     621.0   \
# y
# -40.0 -1.711300 -1.711300 -1.711300 -1.711300 -1.711300 -1.711300 -1.711300
# -38.0 -1.692640 -1.692640 -1.692640 -1.692640 -1.692640 -1.692640 -1.692640
# -36.0 -1.668900 -1.668900 -1.668900 -1.668900 -1.668900 -1.668900 -1.668900
# -34.0 -1.645750 -1.645750 -1.645750 -1.645750 -1.645750 -1.645750 -1.645750
# -32.0 -1.623810 -1.623810 -1.623810 -1.623810 -1.623810 -1.623810 -1.623810
# -30.0 -1.599850 -1.599850 -1.599850 -1.599850 -1.599850 -1.599850 -1.599850
# -28.0 -1.571160 -1.571160 -1.571160 -1.571160 -1.571160 -1.571160 -1.571160
# -26.0 -1.545560 -1.545560 -1.545560 -1.545560 -1.545560 -1.545560 -1.545560
# -24.0 -1.516220 -1.516220 -1.516220 -1.516220 -1.516220 -1.516220 -1.516220
# -22.0 -1.484310 -1.484310 -1.484310 -1.484310 -1.484310 -1.484310 -1.484310
# -20.0 -1.426250 -1.426250 -1.426250 -1.426250 -1.426250 -1.426250 -1.426250
# -18.0 -1.303050 -1.303050 -1.303050 -1.303050 -1.303050 -1.303050 -1.303050
# -16.0 -1.160970 -1.160970 -1.160970 -1.160970 -1.160970 -1.160970 -1.160970
# -14.0 -1.004910 -1.004910 -1.004910 -1.004910 -1.004910 -1.004910 -1.004910
# -12.0 -0.802469 -0.802469 -0.802469 -0.802469 -0.802469 -0.802469 -0.802469
# -10.0  0.311567  0.311567  0.311567  0.311567  0.311567  0.311567  0.311567
# -8.0   1.875270  1.875270  1.875270  1.875270  1.875270  1.875270  1.875270
# -6.0   3.472590  3.472590  3.472590  3.472590  3.472590  3.472590  3.472590
# -4.0   5.068250  5.068250  5.068250  5.068250  5.068250  5.068250  5.068250
# -2.0   6.575120  6.575120  6.575120  6.575120  6.575120  6.575120  6.575120
#
# x        727.9     853.2     1000.0
# y
# -40.0 -1.711300 -1.711300 -1.711300
# -38.0 -1.692640 -1.692640 -1.692640
# -36.0 -1.668900 -1.668900 -1.668900
# -34.0 -1.645750 -1.645750 -1.645750
# -32.0 -1.623810 -1.623810 -1.623810
# -30.0 -1.599850 -1.599850 -1.599850
# -28.0 -1.571160 -1.571160 -1.571160
# -26.0 -1.545560 -1.545560 -1.545560
# -24.0 -1.516220 -1.516220 -1.516220
# -22.0 -1.484310 -1.484310 -1.484310
# -20.0 -1.426250 -1.426250 -1.426250
# -18.0 -1.303050 -1.303050 -1.303050
# -16.0 -1.160970 -1.160970 -1.160970
# -14.0 -1.004910 -1.004910 -1.004910
# -12.0 -0.802469 -0.802469 -0.802469
# -10.0  0.311567  0.311567  0.311567
# -8.0   1.875270  1.875270  1.875270
# -6.0   3.472590  3.472590  3.472590
# -4.0   5.068250  5.068250  5.068250
# -2.0   6.575120  6.575120  6.575120

# %%
plt.figure(figsize=(12,6))
ax = sns.heatmap(df_amplitude, cmap='gnuplot')
ax.set_xlabel("Input width (ns)")
ax.set_ylabel("Input amplitude (V)")
plt.grid(True, which="both")

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_title("Disturbance amplitude on pre-regulator output (ns)")
plt.plot()
plt.tight_layout()
plt.savefig("../../src/4/figures/vpre_cz_V2_amplitude.png", pad_inches=0.3)
plt.show()

# %%
plt.figure(figsize=(12,6))
#ax = sns.heatmap(df_width, cmap='gnuplot', norm=LogNorm(vmin=df_width.values.min(), vmax=df_width.values.max()))
ax = sns.heatmap(df_width, cmap='gnuplot')
ax.set_xlabel("Input width (ns)")
ax.set_ylabel("Input amplitude (V)")
plt.grid(True, which="both")

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_title("Disturbance width on pre-regulator output (ns)")
#plt.xscale('log')
plt.plot()
plt.tight_layout()
plt.savefig("../../src/4/figures/vpre_cz_v2_width.png", pad_inches=0.3)
plt.show()
